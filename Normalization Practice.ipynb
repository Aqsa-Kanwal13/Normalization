# %% [markdown]
# # Min-Max Scalling

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("wine_data.csv",header=0,usecols=[0,1,2])
df.columns=['Class label','Alcohol','Malic acid']

# %%
dfcopy=df.copy()

# %%
dfcopy
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    13.20        1.78
# 1              1    13.16        2.36
# 2              1    14.37        1.95
# 3              1    13.24        2.59
# 4              1    14.20        1.76
# ..           ...      ...         ...
# 172            3    13.71        5.65
# 173            3    13.40        3.91
# 174            3    13.27        4.28
# 175            3    13.17        2.59
# 176            3    14.13        4.10
#
# [177 rows x 3 columns]

# %%
dfcopy["Class label"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
dfcopy["Class label"].value_counts()
# Out:
# Class label
# 2    71
# 1    58
# 3    48
# Name: count, dtype: int64

# %%
sns.kdeplot(dfcopy['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(dfcopy['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %% [markdown]
# # Train_Test_Split

# %%
X=dfcopy[['Alcohol','Malic acid']]
y=dfcopy['Class label']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#      Alcohol  Malic acid
# 22     12.85        1.60
# 108    11.61        1.35
# 174    13.27        4.28
# 144    13.16        3.57
# 71     13.49        1.66
# ..       ...         ...
# 103    12.51        1.73
# 67     13.34        0.94
# 117    12.77        3.43
# 47     14.10        2.02
# 172    13.71        5.65
#
# [123 rows x 2 columns]

# %% [markdown]
# # Min_Max Scaller

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MMS=MinMaxScaler()

# %%
X_train_scaled=MMS.fit_transform(X_train)
X_test_scaled=MMS.transform(X_test)

# %%
X_train_scaled=pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_train_scaled
# Out:
#       Alcohol  Malic acid
# 0    0.489247    0.144603
# 1    0.155914    0.093686
# 2    0.602151    0.690428
# 3    0.572581    0.545825
# 4    0.661290    0.156823
# ..        ...         ...
# 118  0.397849    0.171079
# 119  0.620968    0.010183
# 120  0.467742    0.517312
# 121  0.825269    0.230143
# 122  0.720430    0.969450
#
# [123 rows x 2 columns]

# %%
np.round(X_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    123.0       123.0
# mean      13.0         2.3
# std        0.8         1.2
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.8
# 75%       13.6         3.1
# max       14.8         5.8

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    123.0       123.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.1
# 50%        0.5         0.2
# 75%        0.7         0.4
# max        1.0         1.0

# %%
fig,(ax1, ax2)=plt.subplots(ncols=2, figsize=(12, 5))
ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
ax2.set_title("After Scaling")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 fig,(ax1, ax2)=plt.subplots(ncols=2, figsize=(12, 5))
# ----> 2 ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],)
#       3 ax1.set_title("Before Scaling")
#       4 ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
#
# NameError: name 'X_train' is not defined

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2, figsize=(12, 5))
# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)
# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
fig,(ax1, ax2)=plt.subplots(ncols=2, figsize=(12, 5))
# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
# after scaling
ax2.set_title('Alcohol Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2, figsize=(12, 5))
# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(X_train['Malic acid'], ax=ax1)
# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()
